# %% [markdown]
# ## 데이터 로드하기(Data Load)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import TensorDataset # 텐서데이터셋
from torch.utils.data import DataLoader # 데이터로더

x_train  =  torch.FloatTensor([[73,  80,  75],
                               [93,  88,  93],
                               [89,  91,  90],
                               [96,  98,  100],
                               [73,  66,  70]])
y_train  =  torch.FloatTensor([[152],  [185],  [180],  [196],  [142]])

dataset = TensorDataset(x_train, y_train)

dataloader = DataLoader(dataset, batch_size=2, shuffle=True)

model = nn.Linear(3,1)
optimizer = torch.optim.SGD(model.parameters(), lr=1e-5)

nb_epochs = 20
for epoch in range(nb_epochs + 1):
  for batch_idx, samples in enumerate(dataloader):
    # print(batch_idx)
    # print(samples)
    x_train, y_train = samples
    # H(x) 계산
    prediction = model(x_train)

    # cost 계산
    cost = F.mse_loss(prediction, y_train)

    # cost로 H(x) 계산
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    print('Epoch {:4d}/{} Batch {}/{} Cost: {:.6f}'.format(
        epoch, nb_epochs, batch_idx+1, len(dataloader),
        cost.item()
        ))
# Out:
# Epoch    0/20 Batch 1/3 Cost: 18113.031250
# Epoch    0/20 Batch 2/3 Cost: 13606.365234
# Epoch    0/20 Batch 3/3 Cost: 3158.758789
# Epoch    1/20 Batch 1/3 Cost: 614.280884
# Epoch    1/20 Batch 2/3 Cost: 223.100357
# Epoch    1/20 Batch 3/3 Cost: 18.643747
# Epoch    2/20 Batch 1/3 Cost: 19.306606
# Epoch    2/20 Batch 2/3 Cost: 13.409180
# Epoch    2/20 Batch 3/3 Cost: 14.974618
# Epoch    3/20 Batch 1/3 Cost: 1.572680
# Epoch    3/20 Batch 2/3 Cost: 5.139914
# Epoch    3/20 Batch 3/3 Cost: 4.931522
# Epoch    4/20 Batch 1/3 Cost: 4.718881
# Epoch    4/20 Batch 2/3 Cost: 3.676771
# Epoch    4/20 Batch 3/3 Cost: 4.916083
# Epoch    5/20 Batch 1/3 Cost: 4.925599
# Epoch    5/20 Batch 2/3 Cost: 5.891345
# Epoch    5/20 Batch 3/3 Cost: 4.317272
# Epoch    6/20 Batch 1/3 Cost: 1.479639
# Epoch    6/20 Batch 2/3 Cost: 5.155166
# Epoch    6/20 Batch 3/3 Cost: 4.963698
# Epoch    7/20 Batch 1/3 Cost: 2.518631
# Epoch    7/20 Batch 2/3 Cost: 7.818258
# Epoch    7/20 Batch 3/3 Cost: 1.848398
# Epoch    8/20 Batch 1/3 Cost: 0.933217
# Epoch    8/20 Batch 2/3 Cost: 5.458080
# Epoch    8/20 Batch 3/3 Cost: 5.373163
# Epoch    9/20 Batch 1/3 Cost: 4.680099
# Epoch    9/20 Batch 2/3 Cost: 4.139289
# Epoch    9/20 Batch 3/3 Cost: 3.454269
# Epoch   10/20 Batch 1/3 Cost: 2.878746
# Epoch   10/20 Batch 2/3 Cost: 4.164521
# Epoch   10/20 Batch 3/3 Cost: 7.741124
# Epoch   11/20 Batch 1/3 Cost: 2.665475
# Epoch   11/20 Batch 2/3 Cost: 3.805750
# Epoch   11/20 Batch 3/3 Cost: 4.378551
# Epoch   12/20 Batch 1/3 Cost: 4.970436
# Epoch   12/20 Batch 2/3 Cost: 1.165942
# Epoch   12/20 Batch 3/3 Cost: 6.671141
# Epoch   13/20 Batch 1/3 Cost: 3.888604
# Epoch   13/20 Batch 2/3 Cost: 3.827931
# Epoch   13/20 Batch 3/3 Cost: 5.135131
# Epoch   14/20 Batch 1/3 Cost: 3.995289
# Epoch   14/20 Batch 2/3 Cost: 6.095413
# Epoch   14/20 Batch 3/3 Cost: 5.516578
# Epoch   15/20 Batch 1/3 Cost: 4.162851
# Epoch   15/20 Batch 2/3 Cost: 2.268414
# Epoch   15/20 Batch 3/3 Cost: 6.353729
# Epoch   16/20 Batch 1/3 Cost: 3.877849
# Epoch   16/20 Batch 2/3 Cost: 2.445404
# Epoch   16/20 Batch 3/3 Cost: 4.114888
# Epoch   17/20 Batch 1/3 Cost: 4.436805
# Epoch   17/20 Batch 2/3 Cost: 3.241075
# Epoch   17/20 Batch 3/3 Cost: 1.546064
# Epoch   18/20 Batch 1/3 Cost: 3.781215
# Epoch   18/20 Batch 2/3 Cost: 0.973137
# Epoch   18/20 Batch 3/3 Cost: 9.515007
# Epoch   19/20 Batch 1/3 Cost: 2.476859
# Epoch   19/20 Batch 2/3 Cost: 4.487986
# Epoch   19/20 Batch 3/3 Cost: 2.540380
# Epoch   20/20 Batch 1/3 Cost: 1.065400
# Epoch   20/20 Batch 2/3 Cost: 3.961052
# Epoch   20/20 Batch 3/3 Cost: 7.583159

# %%
# 임의의 입력 [73, 80, 75]를 선언
new_var =  torch.FloatTensor([[73, 80, 75]])
# 입력한 값 [73, 80, 75]에 대해서 예측값 y를 리턴받아서 pred_y에 저장
pred_y = model(new_var)
print("훈련 후 입력이 73, 80, 75일 때의 예측값 :", pred_y)
# Out:
# 훈련 후 입력이 73, 80, 75일 때의 예측값 : tensor([[154.2984]], grad_fn=<AddmmBackward0>)
