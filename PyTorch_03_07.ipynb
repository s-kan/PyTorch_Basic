# %% [markdown]
# ## 커스텀 데이터셋(Custom Dataset)으로 선형 회귀 구현하기

# %%
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# Dataset 상속
class CustomDataset(Dataset):
  def __init__(self):
    self.x_data = [[73, 80, 75],
                   [93, 88, 93],
                   [89, 91, 90],
                   [96, 98, 100],
                   [73, 66, 70]]
    self.y_data = [[152], [185], [180], [196], [142]]

  # 총 데이터의 개수를 리턴
  def __len__(self):
    return len(self.x_data)

  # 인덱스를 입력받아 그에 맵핑되는 입출력 데이터를 파이토치의 Tensor 형태로 리턴
  def __getitem__(self, idx):
    x = torch.FloatTensor(self.x_data[idx])
    y = torch.FloatTensor(self.y_data[idx])
    return x, y

dataset = CustomDataset()
dataloader = DataLoader(dataset, batch_size=2, shuffle=True)

model = torch.nn.Linear(3,1)
optimizer = torch.optim.SGD(model.parameters(), lr=1e-5)

nb_epochs = 20
for epoch in range(nb_epochs + 1):
  for batch_idx, samples in enumerate(dataloader):
    # print(batch_idx)
    # print(samples)
    x_train, y_train = samples
    # H(x) 계산
    prediction = model(x_train)

    # cost 계산
    cost = F.mse_loss(prediction, y_train)

    # cost로 H(x) 계산
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    print('Epoch {:4d}/{} Batch {}/{} Cost: {:.6f}'.format(
        epoch, nb_epochs, batch_idx+1, len(dataloader),
        cost.item()
        ))
# Out:
# Epoch    0/20 Batch 1/3 Cost: 31900.152344
# Epoch    0/20 Batch 2/3 Cost: 10344.373047
# Epoch    0/20 Batch 3/3 Cost: 1796.396606
# Epoch    1/20 Batch 1/3 Cost: 1071.172363
# Epoch    1/20 Batch 2/3 Cost: 382.561768
# Epoch    1/20 Batch 3/3 Cost: 89.859901
# Epoch    2/20 Batch 1/3 Cost: 21.133791
# Epoch    2/20 Batch 2/3 Cost: 26.465872
# Epoch    2/20 Batch 3/3 Cost: 21.407284
# Epoch    3/20 Batch 1/3 Cost: 3.053480
# Epoch    3/20 Batch 2/3 Cost: 7.547048
# Epoch    3/20 Batch 3/3 Cost: 7.640919
# Epoch    4/20 Batch 1/3 Cost: 8.052949
# Epoch    4/20 Batch 2/3 Cost: 6.335142
# Epoch    4/20 Batch 3/3 Cost: 5.553841
# Epoch    5/20 Batch 1/3 Cost: 3.842988
# Epoch    5/20 Batch 2/3 Cost: 7.978883
# Epoch    5/20 Batch 3/3 Cost: 4.794106
# Epoch    6/20 Batch 1/3 Cost: 6.162149
# Epoch    6/20 Batch 2/3 Cost: 4.027236
# Epoch    6/20 Batch 3/3 Cost: 6.937166
# Epoch    7/20 Batch 1/3 Cost: 1.516544
# Epoch    7/20 Batch 2/3 Cost: 15.165634
# Epoch    7/20 Batch 3/3 Cost: 3.778603
# Epoch    8/20 Batch 1/3 Cost: 6.276583
# Epoch    8/20 Batch 2/3 Cost: 5.816776
# Epoch    8/20 Batch 3/3 Cost: 2.822068
# Epoch    9/20 Batch 1/3 Cost: 6.460720
# Epoch    9/20 Batch 2/3 Cost: 6.317727
# Epoch    9/20 Batch 3/3 Cost: 1.506103
# Epoch   10/20 Batch 1/3 Cost: 6.547911
# Epoch   10/20 Batch 2/3 Cost: 4.117571
# Epoch   10/20 Batch 3/3 Cost: 6.617257
# Epoch   11/20 Batch 1/3 Cost: 7.361384
# Epoch   11/20 Batch 2/3 Cost: 2.650325
# Epoch   11/20 Batch 3/3 Cost: 11.513417
# Epoch   12/20 Batch 1/3 Cost: 5.751746
# Epoch   12/20 Batch 2/3 Cost: 3.292103
# Epoch   12/20 Batch 3/3 Cost: 8.378841
# Epoch   13/20 Batch 1/3 Cost: 2.197253
# Epoch   13/20 Batch 2/3 Cost: 14.805931
# Epoch   13/20 Batch 3/3 Cost: 2.739172
# Epoch   14/20 Batch 1/3 Cost: 4.282599
# Epoch   14/20 Batch 2/3 Cost: 4.321105
# Epoch   14/20 Batch 3/3 Cost: 13.932340
# Epoch   15/20 Batch 1/3 Cost: 3.267808
# Epoch   15/20 Batch 2/3 Cost: 5.707082
# Epoch   15/20 Batch 3/3 Cost: 8.205896
# Epoch   16/20 Batch 1/3 Cost: 4.704963
# Epoch   16/20 Batch 2/3 Cost: 5.948468
# Epoch   16/20 Batch 3/3 Cost: 6.616001
# Epoch   17/20 Batch 1/3 Cost: 5.316788
# Epoch   17/20 Batch 2/3 Cost: 6.039479
# Epoch   17/20 Batch 3/3 Cost: 6.328599
# Epoch   18/20 Batch 1/3 Cost: 0.218178
# Epoch   18/20 Batch 2/3 Cost: 13.881266
# Epoch   18/20 Batch 3/3 Cost: 7.952872
# Epoch   19/20 Batch 1/3 Cost: 6.329942
# Epoch   19/20 Batch 2/3 Cost: 6.210578
# Epoch   19/20 Batch 3/3 Cost: 1.494515
# Epoch   20/20 Batch 1/3 Cost: 10.797528
# Epoch   20/20 Batch 2/3 Cost: 4.785592
# Epoch   20/20 Batch 3/3 Cost: 4.540757

# %%
# 임의의 입력 [73, 80, 75]를 선언
new_var =  torch.FloatTensor([[73, 80, 75]])
# 입력한 값 [73, 80, 75]에 대해서 예측값 y를 리턴받아서 pred_y에 저장
pred_y = model(new_var)
print("훈련 후 입력이 73, 80, 75일 때의 예측값 :", pred_y)
# Out:
# 훈련 후 입력이 73, 80, 75일 때의 예측값 : tensor([[153.3913]], grad_fn=<AddmmBackward0>)
